# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

# %%
# Load the list from the text file
comm = []
with open('comm2.txt', 'r') as f:
    for line in f:
        comm.append(line.strip())

# %%
def func_find_threshold(num_words):
    # Sort the num_words list in descending order
    sorted_num_words = sorted(num_words, reverse=True)
    
    # Define the sample size as a percentage of the total data points
    sample_size_percent = 0.4  # Change this value as needed
    
    # Calculate the number of records to consider based on the sample size percentage
    num_records = int(len(sorted_num_words) * sample_size_percent)
    
    # Calculate the avg_topn as the average of the top n records
    n = int(sample_size_percent * 100)  # Change this value as needed
    avg_topn = sum(sorted_num_words[:n]) / n
    
    # Create a new list to store data points above the threshold
    above_threshold = [num for num in sorted_num_words if num >= avg_topn * 0.4]
    
    # Calculate the average of the above_threshold list
    average_above_threshold = sum(above_threshold) / len(above_threshold)
    
    print("Average of the top", n, "records:", avg_topn)
    print("Data points at least 40% or above the avg_topn:", above_threshold)
    print("Average of the data points above the threshold:", average_above_threshold)
    
    return min(above_threshold)

# %%
text_comm = [element for element in comm if any(char.isalpha() for char in element)]

print('the original comm file contains - ' + str(len(comm)) + ' lines of text')
print('after filtering for clear texts, the file contains - ' + str(len(text_comm)) + ' lines if text')
# Out:
# the original comm file contains - 444 lines of text
# after filtering for clear texts, the file contains - 436 lines if text

# %%
plt.figure(figsize=(10, 5))

# Calculate the number of words in each element
num_words = [len(text.split()) for text in text_comm]

# Plotting the distribution of the number of words
sns.histplot(num_words, kde=True)
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.title('Original Distribution of Number of Words')
plt.show()

plt.figure(figsize=(10, 5))

# Calculate the average number of alphabetical characters in each word
#avg_alphabet_chars = [sum(len(word) for word in text.split() if word.isalpha()) / len(text.split()) for text in filter_comm]
avg_alphabet_chars = [sum(len(re.findall('[a-zA-Z]', word)) for word in text.split()) / len(text.split()) for text in text_comm]

# Plotting the distribution of the average number of alphabetical characters
sns.histplot(avg_alphabet_chars, kde=True)
plt.xlabel('Average Number of Alphabetical Characters')
plt.ylabel('Frequency')
plt.title('Distribution of Average Number of Alphabetical Characters in Words')
plt.show()

# %%
threshold = func_find_threshold(num_words)
text_comm2 = [element for element in text_comm if len(element.split()) >= threshold]
# Out:
# Average of the top 40 records: 110.225
# Data points at least 40% or above the avg_topn: [796, 205, 197, 190, 182, 167, 167, 141, 136, 134, 134, 104, 89, 89, 83, 82, 81, 79, 77, 75, 70, 70, 68, 67, 65, 65, 64, 62, 60, 59, 59, 58, 56, 56, 56, 55, 54, 53, 52, 52, 51, 51, 50, 50, 50, 49, 47, 47, 47, 46, 46, 46, 45, 45]
# Average of the data points above the threshold: 94.05555555555556

# %% [markdown]
# # POS analysis and data cleaning

# %%
# import spacy

# nlp = spacy.load('en_core_web_sm')

# pos_tags = []
# text = "After 70 league games spread over a period of a littleover 7 weeks, we finally have four survivors contesting to take home the prized IPL trophy. Will MI be 6th time champs? Can CSK grab a 5th title? Will Gujarat Titans continue their winning spree and defend their title or will Lucknow Super Giantsbecome a first time champions? Lot to play for as IPL 2023 reaches the home stretch with today's Qualifier 1. The Titans cruised through the league phase once again and were comfortably the best team on display, they just didn't confirm their place in the playoffs, but they did so emphatically. On the other hand, the Super Kings had to wait until their final game of the league, but they do have the knack of winning big moments, especially when playing at home. The winner of tonight's game will go through to Sunday's final while the loser will wait for tomorrow's winner in QF 2 on 26th in Ahmedabad. CSK not just have home advantage tonight, but they're the better rested team, having played their last league match on Saturday. On the other hand, Titans's last match spilled into the wee hours of yesterday and they'd to travel as well. Would that be a telling factor today?"

# doc = nlp(text)
# tags = [(token.text, token.pos_) for token in doc]
# tags

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

pos_counts = []

for text in text_comm2:
    doc = nlp(text)
    pos_count = {}

    for token in doc:
        pos = token.pos_
        if pos in pos_count:
            pos_count[pos] += 1
        else:
            pos_count[pos] = 1

    pos_counts.append(pos_count)
# pos_counts

# %%
# Extract unique POS tags
unique_pos_tags = sorted(set([pos for pos_count in pos_counts for pos in pos_count.keys()]))

# Create an array to store the counts for each POS tag
pos_counts_array = np.zeros((len(pos_counts), len(unique_pos_tags)))

# Fill in the array with the counts
for i, pos_count in enumerate(pos_counts):
    for j, pos_tag in enumerate(unique_pos_tags):
        pos_counts_array[i, j] = pos_count.get(pos_tag, 0)

# Plotting the stacked bar chart
plt.figure(figsize=(12, 8))
plt.bar(range(len(pos_counts)), pos_counts_array.T[0], label=unique_pos_tags[0])

for i in range(1, len(unique_pos_tags)):
    plt.bar(range(len(pos_counts)), pos_counts_array.T[i], bottom=np.sum(pos_counts_array.T[:i], axis=0),
            label=unique_pos_tags[i])

plt.xlabel('Line of Text')
plt.ylabel('Count')
plt.title('POS Tag Distribution for Each Line of Text')
plt.xticks(range(len(pos_counts)), range(1, len(pos_counts) + 1))
plt.legend(loc='upper right')
plt.show()

# %%
text_comm3 = []

for i, text in enumerate(text_comm2):
    pos_count = pos_counts[i]
    noun_count = pos_count.get('PROPN', 0)
    punctuation_count = pos_count.get('PUNCT', 0)
    total_count = sum(pos_count.values())

    if (noun_count + punctuation_count) / total_count <= 0.6:
        text_comm3.append(text)
text_comm3
# Out:
# ["So, that's it from us for this game! Dhoni couldn't finish it off in style tonight but he tried his best. RR have gone to the top of the table with this win. We have witnessed close finishes in the last four days of the IPL and it has certainly kept us on the edge of our seats! Do join us tomorrow for another high-octane clash as PBKS have returned home and they will host GT. Till then, goodbye and cheers!",
#  "Ravichandran Ashwin | Player of the Match: I surprise people I guess. Whenever I walk out to bat, people assume I just took that decision and came out, but that's a role given to me, we lost Sanju and I had to do a job. I am far better at judging my strengths, I take a few balls to get going. Every batting innings, I am padded up from the start. It's not an easy thing but it is good. I came off with good Test form. I feel I am able to get good grip and drop on the ball at the right lengths. If I was not able to do those things in the two years (with Punjab Kings) then I wouldn't be able to do it here. Success or failure, it has to be on my own terms.",
#  "Sanju Samson | RR captain: You have to give credit to the boys. The bowlers kept their cool at the end and bowled really well, we also held on to our catches. I don't have good memories at Chepauk, never won here and wanted to win today. The ball was gripping and hence, we brought Zampa in as the impact player. We had a good powerplay with Rutu getting out and the thought was if we can get out of the powerplay without giving away too much then we have the spinners to do the job. Last two overs were tensed, I tried to push it deep but you are never safe with that guy (Dhoni). You have to have respect for that guy and to what he can do. Nothing works against him.",
#  "Yuzvendra Chahal: The wicket was gripping, and I focused on varying my pace. I didn't want to give them the pace. This is my second season with Ashwin and we have bowled well in partnership. Zampa has played for Australia and we keep discussing in the nets as to how to bowl. Sandeep backed himself and when Mahi bhai is batting, you need to have self-belief and Sandeep pulled it off and that is why runs were not scored. Close games always boost you up for the upcoming games.",
#  'RR vs CSK at Chepauk 2008 - Won by 10 runs  2010 - Lost by 23 runs 2011 - Lost by 8 wickets  2012 - Lost by 7 wickets 2013 - Lost by 5 wickets  2015 - Lost by 12 runs 2019 - Lost by 8 runs 2023 - Won by 3 runs',
#  'Sandeep Sharma: I wanted to deliver yorkers in the last over. I was bowling good yorkers in the nets. The leg-side was big, but I missed my mark and bowled a couple of low full-tosses and both went for sixes. Then I changed my angle and it worked. I bowled over the wicket to Jadeja and I wanted to keep it away from his reach.',
#  "MS Dhoni | CSK captain: I think in the middle overs we needed a bit more strike rotation, there wasn't much for the spinners but they had experienced spinners and we could not rotate strike. It was not that difficult and the ownership (of the loss) should come from the batters. It was good that we could reach striking distance (of the target) as we were the last pair. It really affects NRR when you get to the last phase of the tournament. You see the field, see the bowler and what the bowler is trying to do, after that just stand still and wait for them to commit the mistake, if they bowl in good areas then good luck to them. I would wait for it and that is something which has worked for me, you need to back your strength and my strength is to hit straight. There was a bit of dew and once the ball went to the outfield it became easier for the batters. Overall I was very happy with the bowlers. I really didn't know it was my 200th (game as CSK skipper) and milestones don't really matter for me, it is about how you're performing and the results.",
#  "23:23 Local Time, 17:53 GMT, 23:23 IST: The RR players have held their nerves, to win by only 3 runs! Dhoni and Jadeja tried their best but couldn't pull off a fairytale win for CSK! Gaikwad got out early but Conway and Rahane stitched a 50-run stand together, keeping the scoreboard ticking. But, the spinners were getting grip and turn as expected and they kept the run rate in check. It was always going to be a battle against spin on this track and Chahal and Ashwin rose to the occasion. In their combined 8 overs, they only conceded 52 runs and took 4 wickets. CSK kept losing wickets due to the asking rate rising but Jadeja and Dhoni gave the hosts a last ray of hope! 40 was needed off the last 2 overs! Holder was taken away for 19 runs in the penultimate over. 20 was needed off the last over and Dhoni would have backed himself. Sandeep missed his mark and he was hit for two consecutive sixes. But, he delivered yorkers when it was needed and Dhoni couldn't finish it off. Stick around for the presentations..",
#  "Sandeep Sharma to Dhoni, 1 run, brilliant from Sandeep Sharma! Not a memorable finish for Dhoni but he tried his best! A yorker outside off, Dhoni can't get underneath it as he whips it straight to deep mid-wicket. Sandeep Sharma has a beaming smile on his face and he his hugged by his teammates. What a game, amazing",
#  'Dhoni on strike and 5 needed off the last ball! He has done it a lot of times for India and in the IPL as well. Will he pull off another memory to be cherished for a lifetime? Tension in the crowd but Dhoni looks unfazed',
#  'Timeout! CSK need 59 off 24 balls! Looks unlikely at the stage, but you never write Dhoni off! Till he is at the crease, anything is possible. RR on top at the moment. Two overs of spin left as well and the ball has certainly gripped. CSK need a MSD special',
#  'Overs 7-15 summary: --> 15 comes off the 9th over from Zampa --> Ashwin breaks the partnership by getting Rahane --> Kuldeep Sen bowls a tight 11th over --> Dube is trapped LBW by Ashwin --> Replays show it to be missing leg, no review by Dube --> Zampa dismisses Mo to further strengthen RR --> Rayudu falls cheaply too as the Impact sub fails --> Conway reaches 50 off 37 balls and gets out',
#  'Chahal to Conway, out Caught by Jaiswal!! Conway departs just after his Fifty! The asking rate has gone up over 12 and CSK are crumbling! Chahal pushes this one wider outside off, Conway has to reach out to it as he goes for a loft but gets it off the toe-end over extra cover. Jaiswal moves back, keeps his eyes on the ball, takes the catch, and then tumbles over. Conway c Jaiswal b Chahal 50(38) [4s-6]',
#  'Chahal to Conway, 3 runs, full on leg, slog swept past the right of short fine leg. The fielder from the deep moves to his left and dives to stop a run for his side. 50 for Conway! Has been a decent knock but he needs support',
#  "Chahal to Rayudu, out Caught by Hetmyer!! Another one bites the dust! The Impact player fails to make an impact. The flipper from Chahal and it's on a length on middle. Skids a bit and hurries Rayudu a bit. He miscues his pull shot towards deep mid-wicket. Hetmyer moves to his right, gets low, and dives to take a fine catch. Rayudu c Hetmyer b Chahal 1(2)",
#  "Zampa to Moeen Ali, out Caught by Sandeep Sharma!! CSK are losing their way! Zampa gets his first wicket! The trial by spin is certainly taking a toll on CSK. Googly around leg, Moeen Ali goes for the slog sweep but doesn't get it off the middle of the bat. The ball skies towards deep backward square leg. Sandeep moves to his left, gets low, and manages to hold onto it. Moeen Ali c Sandeep Sharma b Zampa 7(10)",
#  "Chahal to Moeen Ali, no run, oh, that stayed low! Also, seemed there was an edge. Is that a dropped chance?  Quicker and flatter outside off, Moeen Ali looks to cut and gets an under-edge but Samson can't hold on to it. Moeen also lost control of his bat, it flew off his hand and fell near short leg",
#  "Ashwin to Shivam Dube, out Lbw!! Ashwin is turning it around at Chepauk! Smart bowling from him. This one pitches on a length and skids through. Shivam Dube is caught in the crease as he tries to counter it but misses and is hit on the front pad. An appeal follows and the umpire rules it out. Oh ho, replay rolls in and Ball Tracking shows that it would have gone down leg. That certainly didn't look that way in real time. Shivam Dube lbw b Ashwin 8(9) [4s-1]",
#  'Ashwin to Shivam Dube, no run, Shivam Dube looks to cut the flatter one bur misses and Samson takes the bails off. It is sent upstairs. For a moment, his back foot seemed to be on the crease but he got it back in time',
#  "Ashwin to Rahane, out Lbw!! Ashwin breaks the partnership. Rahane and Conway have a discussion regarding the review, but looks like the former himself didn't want to send it upstairs. Carrom ball and Rahane premeditated the sweep, the length was too full and he ended up playing all over it, struck low on the pad and right in front of the stumps. That would have crashed into leg-stump and umpire Vinod Seshan made the right call. Rahane lbw b Ashwin 31(19) [4s-2 6s-1]",
#  'Zampa to Rahane, 2 wides, stifled appeal for LBW. Drifting down and Rahane misses the sweep, the ball brushes the pad on the way to short fine. In fact, CSK have reviewed for a wide and UltraEdge shows no spike as it passes Rahane. Zampa is having a word with the umpire but will have to bowl the extra delivery',
#  'Time out! This match is right in the balance. Some of the RR players are carrying towels but none have used them which is a good sign and means dew has not come into effect. They will hope for the conditions to remain the same as they still have 9 overs of spin up their sleeve. The asking rate is 9.5 and that should not worry CSK as of now.',
#  'Overs 1-6 summary: --> Sandeep Sharma gets Gaikwad early on --> CSK up the rate with two fours in the fourth over --> Samson brings on Zampa in the 5th over --> Conway sweeps Zampa for a boundary --> Tough chance put down by Sandeep Sharma of Conway --> Rahane slams Ashwin for a biggie --> At the end of the powerplay, CSK are 45/1',
#  'Zampa to Conway, FOUR, dropped! Tough chance but Sandeep got both hands. Conway goes for the sweep and hits it hard, Sandeep times his jump correctly but was not able to deal with the pace on the ball and allows it to burst through his fingers',
#  'Sandeep Sharma to Gaikwad, out Caught by Jaiswal!! No Boult, no problem. Sandeep provides the early breakthrough and it is the big wicket of the in-form Gaikwad. Angled in and Gaikwad wanted to whip it through the leg-side, but all he manages is a leading edge and the ball goes high, Jaiswal calls for it and hangs on to a good catch. Gaikwad c Jaiswal b Sandeep Sharma 8(10) [4s-1]',
#  "Jos Buttler: It started off as a really good wicket in the powerplay but it slowed down. Jadeja then bowled really well. It’s a decent score we have got but it will come down to the dew and how the wicket plays in the second half. In the powerplay, you are always trying to take advantage. But because we lost a few wickets, I had to extend a partnership and take it deeper. It is disappointing to get out in the death. But we got a good score. (On Jadeja) He bowls fast and gets it to turn. It's hard to see the variations - one spinning and one skidding. But we have Ashwin, Chahal and Zampa. We had a really good success with our spinners and traditionally it is a pretty good venue for spin.",
#  '21:14 Local Time, 15:44 GMT: RR will be a tad disappointed for just making 175. They had the platform when Padikkal and Buttler were going well but then the game turned in one Jadeja over. Padikkal and Samson went and Ashwin was dropped first ball in that over. From there, Buttler and Ashwin struggled to force the pace till the latter hit two sixes off Akash Singh to break the shackles. Buttler though totally lost momentum and got out after his fifty. At the end a cameo from Hetmyer helped RR get to 175 when even that was looking doubtful. Again the spinners pulling things back for CSK and credit to MS for trusting Moeen Ali who had a shocker on the field with two drops and a run-out missed, Mo repaid that faith with the big wicket of Buttler. The pitch has help for the spinners and RR have three world-class ones in their team with Zampa as the Impact sub. Back for the chase shortly...',
#  'Tushar Deshpande to Zampa, out Zampa Run Out!! 1 run completed. Dropped but run-out too. Zampa shuffles across and scoops the slower ball to Theekshana at short fine-leg, a sitter is dropped but the batters try to steal a second, the throw to Dhoni is enough who flicks it on to the stumps catching Zampa well short. Zampa run out (Theekshana/Dhoni) 1(1)',
#  "Akash Singh to Dhruv Jurel, out Caught by Shivam Dube!! The wide full-toss outside off works. Dhruv Jurel shuffles across and miscues it to long-off. They check for the height but it's below the waist so RR lose the review for they were the ones reviewing it. Dhruv Jurel c Shivam Dube b Akash Singh 4(6)",
#  'Moeen Ali to Buttler, out Bowled!! Mo gets Buttler. No celebrations or anything from Mo. He has got the big wicket. Nicely tossed up offbreak outside off, Buttler goes for a big slogsweep and misses, the ball turns back in to hit off-stump. Buttler b Moeen Ali 52(36) [4s-1 6s-3]',
#  'Highlights (Overs 7-15) - Buttler takes Moeen to the cleaners, 18 runs - Jadeja breaks the 77-run stand, Padikkal gone - Jadeja bowls a ripper to dismiss Samson for a duck - Ashwin promoted to no. 5 and dropped first ball by Mo, unlucky Jadeja - Jadeja finishes\xa0an impressive spell with figures - 4-0-21-2 - Ashwin smokes two sixes off Akash and departs in the same over',
#  'Akash Singh to Ashwin, out Caught by Magala!! Ashwin holes out. Full and wide outside off, sliced in the air and Magala at extra-cover takes it. Immediately looks at his fingers and calls for the physio. Hopefully he has not done something serious. Ashwin c Magala b Akash Singh 30(22) [4s-1 6s-2]',
#  "Paras: Don't think any other keeper still even comes close to the kind of reflexes MSD has behind the stumps. Hitting sixes to one of fastest bowlers going around Mark Wood, taking the bails off in a flash. Is he even getting old? Truly a legend of the game like no one else, hope to see him keep playing.",
#  "Theekshana to Ashwin, no run, run-out chance missed! Ashwin comes down the track and miscues the drive to cover, is halfway down the track, Mo goes to his left and fumbles, then his throw is well wide of MS who can't get there even with a dive. Ashwin was well out too",
#  'Timeout! CSK have come back so well after the first timeout. Jadeja with wickets and doing a stellar job in his four overs. Ashwin has not played a shot in anger after being dropped first ball. All this while Buttler from the other end, is starved of the strike.',
#  'Jadeja to Ashwin, no run, that unplayable drift in turn away delivery that Jadeja bowls so well, Ashwin looks to flick across the line and misses, sharp turn for Jadeja and MS has the bails off in a flash, Ashwin though did not lift his back foot',
#  'Kunal: RR are thinking to have someone hold one end and allow others to attack from the other, hence Ashwin came out on no. 5. Hopefully this doesn\'t backfire. -- "Or he will have a better idea of the conditions as it is his home ground."',
#  "STAT: This is the third time Ashwin is batting at No.5 in the IPL. The last instance came against CSK at Brabourne last year - which was RR's last league game - and he produced 40*(23) in a successful 152-run chase that ensured RR's second finish in the points table.",
#  'Jadeja to Ashwin, no run, dropped by Mo at slip. Tough chance and Jadeja is holding his hands on his head. Is Mo standing too far forward? This flies off a thick outside-edge as Ashwin looks to defend, went at chest-height, a couple of grabs from Mo and down it goes',
#  'Jadeja to Samson, out Bowled!! What a cracker. Samson falls for a duck again. Fullish and quicker, drifting into middle and leg, Samson made the mistake of going back and then it turns from there, past the back foot block, the off-stump is knocked back. Fine over produces two wickets for CSK. Samson b Jadeja 0(2)',
#  'Highlights (Overs 1-6) - Jaiswal gets going with back to back fours - Deshpande strikes in his first over, Jaiswal gone - Padikkal promoted to no. 3 and he hits a couple of fours in the 3rd over - Moeen drops Padikkal on 14 off Theekshana - Theekshana is smashed for 17 runs in his second over - Jos Buttler completes 3000 IPL runs',
#  'Theekshana to Padikkal, 1 run, dropped by Mo at slip. Went low and to the left of him and he could not react quickly. Was the flatter delivery on the stumps, Padikkal opens the face of the bat and dabs it, hits the left shin of Mo',
#  "Tushar Deshpande to Jaiswal, out Caught by Shivam Dube!! The hard back of a length into the pitch gets Jaiswal. He was in no position to play the pull, rushed by it, he miscues it off the splice and it's an easy catch for Dube at mid-off. Jaiswal c Shivam Dube b Tushar Deshpande 10(8) [4s-2]",
#  'Akash Singh to Jaiswal, FOUR, so poor from Theekshana at third man. A back of a length delivery outside off, Jaiswal cuts and Theekshana gets across and slides to his left, the ball slips under the body, may have just overrun that too, the slide was unnecessary to be honest',
#  'Akash Singh to Jaiswal, no run, loud appeal for LBW but MSD is stoic as always.  Jaiswal on the charge first ball, this is the inswinger and he got an inside-edge onto the pads on the flick, good call not to go for the review',
#  'Dwaine Pretorius: (On what has worked for CSK) The important guys have performed really well, Rutu is in good form, Jadeja is in good form, Santner has bowled really well in the last three games. As a group, we are performing really well and the guys are putting up their hands. Ajinkya coming in his first game and putting in a man of the match performance, we can’t expect anything better from the team and hopefully we can continue tonight. (On his bowling plans) The boundaries are a bit bigger on the squarer side, so force the batters to hit on the square options. Change of pace always a good option. The previous wicket played really good so let’s see how the wicket plays tonight. (On playing under MSD) The calmness he brings to the team, then also the excitement of the crowd, every game feels like a home game. It is awesome to play under him and may he play for many more years to come.',
#  "Adam Zampa: I guess seeing what the surface is like at the time, last time we played here it was a new wicket, I haven't played here for quite a while, but there was a little bit more bounce than compared to some other Indian wickets. I found out this wicket has bounce (while playing for Australia), had a warm-up bowl now and it looks like it is doing the same thing. If we bowl second and it gets wet then it changes the game. Lot of planning goes into it, as a young man I was negligent but I have played a lot of cricket now and you have to bowl to guys' weaknesses, bit of planning and then backing my skill. It is all new to the game and we are trying to work it out ourselves, the new sub rules can change the game quickly, just being ready and grabbing the opportunity when it comes. I have played with Yuzi before as well, we sit back after the game and discuss what we could have done better, we have done that for the last couple of years and are happy to help each other.",
#  "Sanju Samson: We would have liked to bowl first too. We have started well but we need to continue the momentum. We are playing at Chepauk after a long time. We have experience and the youngsters to do that. It has always been a pleasure to come to Chepauk and play here. Boulty misses out due to a small niggle and we have a couple of changes, you will come to know that. It's difficult to keep track with the sub rule.",
#  "MS Dhoni: We will bowl first. It maybe slightly on the slower side, different from the first game. Dew may play a role and it might get better in the second innings. (On his 200th game as CSK captain in the IPL) It feels good and also I feel the crowd has been fantastic. Also the fact that we started in the old stadium, it was very hot and humid. But now it feels like we're playing in Switzerland. It's good to play. We have seen cricket change - how T20 was played at that point of time till now, a lot has changed. The crowd has been fantastic. We have had injury concerns and players were unavailable, but still we have done well. Mitchell Santner and Pretorius make way for Theekshana and Moeen.",
#  'Lots of cracks, not a lot of grass. The surface is firm enough here but fully expect the spinners and cutters to play a major role in this type of surface. The way the openers approach the game in the powerplay can have an impact on the game. In the middle overs, the spinners will come into play. In the game against LSG, the spinners extracted good turn. It is going to turn and there will be a bit of bounce too. The key will be to bowl in the right lengths, on the 5-6 metres area, opines Nick Knight in his pitch report.',
#  "18:18 Local Time, 12:48 GMT: CSK have returned to their fortress and they truly know how to rule the roost in their home conditions and it will certainly be a stern test for RR. MSD will be leading CSK for the 200th time in the IPL and it is a big occasion for him tonight. After losing their opening game, CSK have won two games in a row. RR also have two wins out of three games. With a chance to top the table on offer, expect a humdinger of a contest. If the Chepauk surface plays true to its nature, expect spin to play a substantial part. In the last game here, we saw more than 420 runs scored. Even Dhoni was surprised by the way the surface played but saying all that, the spinners did extract good purchase. These two teams have ticked most boxes so far. Will Dhoni lead CSK to a hat-trick of wins in today's historic game? Or will RR breach CSK's fortress? Stay with us as toss and team lineups will be out in a while..",
#  'Preview by Narbavi R   You don\'t challenge Chennai Super Kings in their own game at Chepauk unless you\'re Rajasthan Royals. The Jaipur outfit have India\'s best offspinner and the best legspinner in their ranks and facing the duo on a turning track can prove to be quite a handful for any side. If needed, they also have the option to draft in Adam Zampa or use Murugan Ashwin as an impact sub.  For the Royals batters, the change in approach is going to be quite massive considering the fact that they played their last two games in batting friendly conditions in Guwahati. But even in turning conditions, their batters may hold the edge over CSK going by history. Jos Buttler\'s record against finger spin in the IPL over the last five years is exceptional as he averages over 100 at a strike rate of 156. Sanju Samson could come to the party as well given his record against left-arm spinners (SR of 161.93).  How will CSK manage to counter all of that is the big question as they eye their third win on the trot after losing the opening game. CSK approach this game on the back of their big win against rivals Mumbai Indians in a contest where their own spin duo of Mitchell Santner and Ravindra Jadeja had a huge say. Maheesh Theekshana is likely to make it a troika on Wednesday (April 12) after arriving in time from New Zealand. In the batting department, Ajinkya Rahane\'s sparkling debut for the franchise gives them plenty of reasons to feel optimistic especially with Ben Stokes set to miss this fixture as well. However, Rahane has had issues against spin even in his pomp in the past and that could well be put to test if he continues to bat at No.3.  However, amidst all the talk of a possible mouth-watering spin battle between these two outfits, we could be in for an anti-climax if the surface turns out to be quite flat at the Chepauk like it was last week against Lucknow Super Giants. Over 420 runs were scored that night and MS Dhoni did admit that he was surprised with how the surface played. Perhaps for a change, the chances of the fortress not being breached could remain high if a similar surface is dished out.  When: Wednesday, April 12 at 19:30 IST  Where: MA Chidambaram Stadium, Chennai  What to expect: Even Dhoni sometimes doesn\'t know what to expect, like he admitted after the LSG game. While the surface that was used in the ODI last month against Australia assisted turn, the one against LSG was a belter.  Teams  Chennai Super Kings  News: Maheesh Theekshana and Matheesha Pathirana have joined the squad ahead of the game. The former is likely to slot in straightaway. Ben Stokes and Deepak Chahar are set to remain on the sidelines but CSK will be boosted by Moeen Ali\'s availability.  Tactics and match-ups: Ruturaj Gaikwad had made a very good start to this year\'s IPL. However, his record against Trent Boult doesn\'t ooze confidence as he has been dismissed by the New Zealand seamer thrice in the space of 21 deliveries. CSK will have to ensure Boult\'s early threat is countered by his New Zealand teammate Devon Conway.  Probable XI: Ruturaj Gaikwad, Devon Conway, Ajinkya Rahane, Moeen Ali, Shivam Dube, Ravindra Jadeja, MS Dhoni (C & WK), Mitchell Santner, Rajvardhan Hangargekar, Maheesh Theekshana, Tushar Deshpande  Rajasthan Royals  Tactics and matchups: CSK have the worst economy rate (11.44) in the powerplay this season. Royals have the ideal batter up top to take full toll of that in the form of Yashasvi Jaiswal. The young left-hander, quite incredibly, is striking close to 200 in the powerplay this season and that phase could well be the difference-maker if the track turns out to be slow.  Probable XI: Yashasvi Jaiswal, Jos Buttler, Sanju Samson (C & WK), Dhruv Jurel/Devdutt Padikkal, Shimron Hetmyer, Riyan Parag, Jason Holder, R Ashwin, M Ashwin, Trent Boult, Yuzvendra Chahal  Did you know:  - Trent Boult has picked 19 wickets in the first over in IPL since 2020  - Since 2022, Maheesh Theekshana has picked 12 wickets at ...

# %%
len(text_comm3)
# Out:
# 52

# %% [markdown]
# # Calculating word frequency

# %%
nlp = spacy.load('en_core_web_sm')

word_counts = []
for i in range(len(text_comm3)):
    doc = nlp(text_comm3[i])
    # Calculate word frequencies, excluding stop words
    word_frequencies = {}
    for token in doc:
        word = token.text.lower()
        if word.isalpha() and word not in STOP_WORDS:
            if word not in word_frequencies:
                word_frequencies[word] = 1
            else:
                word_frequencies[word] += 1

    all_word_frequencies = [(word, freq) for word, freq in word_frequencies.items()]
    #print('received values for line' + str(i))
    word_counts.append(all_word_frequencies)
word_counts
# Out:
# [[('umpires', 1),
#   ('walk', 1),
#   ('ready', 1),
#   ('lots', 1),
#   ('yellow', 1),
#   ('chepauk', 1),
#   ('gt', 1),
#   ('hope', 1),
#   ('silence', 1),
#   ('tonight', 1),
#   ('big', 1),
#   ('toss', 1),
#   ('win', 1),
#   ('hayden', 1),
#   ('sure', 1),
#   ('bat', 1),
#   ('track', 1),
#   ('captains', 1),
#   ('think', 1),
#   ('dew', 1),
#   ('factor', 1),
#   ('shami', 1),
#   ('start', 1),
#   ('titans', 1),
#   ('slip', 1),
#   ('place', 1)],
#  [('runs', 1),
#   ('preparation', 1),
#   ('going', 1),
#   ('tournament', 1),
#   ('good', 1),
#   ('injury', 1),
#   ('free', 1),
#   ('unlike', 1),
#   ('time', 3),
#   ('nature', 1),
#   ('everytime', 1),
#   ('consistent', 1),
#   ('idea', 1),
#   ('process', 1),
#   ('assessing', 1),
#   ('pitch', 2),
#   ('deciding', 1),
#   ('approach', 2),
#   ('important', 2),
#   ('play', 1),
#   ('expressive', 1),
#   ('cricket', 1),
#   ('earlier', 1),
#   ('odd', 1),
#   ('balls', 1),
#   ('lot', 1),
#   ('depends', 1),
#   ('situation', 1),
#   ('left', 2),
#   ('right', 1),
#   ('combo', 1),
#   ('opposition', 1),
#   ('tactics', 1),
#   ('change', 1),
#   ('like', 1),
#   ('bowling', 1),
#   ('spinner', 2),
#   ('arm', 1),
#   ('devon', 1),
#   ('playing', 1),
#   ('fast', 1),
#   ('bowlers', 1),
#   ('played', 1),
#   ('spin', 1),
#   ('season', 1)],
#  [('dry', 1),
#   ('pitch', 1),
#   ('dew', 1),
#   ('factor', 1),
#   ('csk', 1),
#   ('batting', 1),
#   ('losing', 1),
#   ('toss', 1),
#   ('gt', 1),
#   ('impact', 1),
#   ('sub', 1),
#   ('lots', 1),
#   ('confusion', 1),
#   ('head', 2),
#   ('looking', 1),
#   ('useful', 1),
#   ('tips', 1),
#   ('fantasyhandbook', 1),
#   ('cricbuzz', 1),
#   ('plus', 1),
#   ('looks', 1)],
#  [('wanted', 1),
#   ('bowl', 1),
#   ('reason', 1),
#   ('excellent', 1),
#   ('chasing', 1),
#   ('exploited', 1),
#   ('conditions', 1),
#   ('slightly', 1),
#   ('better', 1),
#   ('tournament', 1),
#   ('like', 1),
#   ('boys', 1),
#   ('adapted', 1),
#   ('important', 1),
#   ('straengths', 1),
#   ('confidence', 1),
#   ('level', 1),
#   ('high', 1),
#   ('able', 1),
#   ('lot', 1),
#   ('dew', 1),
#   ('game', 1),
#   ('breeze', 1),
#   ('tonight', 1),
#   ('look', 1),
#   ('dry', 1),
#   ('playing', 1),
#   ('team', 1)],
#  [('bowl', 1),
#   ('heard', 1),
#   ('dew', 1),
#   ('come', 1),
#   ('want', 3),
#   ('know', 1),
#   ('exactly', 1),
#   ('chase', 1),
#   ('told', 1),
#   ('relax', 1),
#   ('getting', 1),
#   ('stay', 1),
#   ('focussed', 1),
#   ('play', 2),
#   ('good', 1),
#   ('cricket', 1),
#   ('smart', 1),
#   ('team', 1),
#   ('way', 1),
#   ('sure', 1),
#   ('best', 1),
#   ('wicket', 1),
#   ('adapted', 1),
#   ('darshan', 1),
#   ('nalkande', 1),
#   ('comes', 1),
#   ('place', 1),
#   ('yash', 1),
#   ('dayal', 1)],
#  [('quick', 2),
#   ('turnaround', 2),
#   ('long', 1),
#   ('season', 1),
#   ('guys', 4),
#   ('played', 1),
#   ('comes', 2),
#   ('semifinal', 1),
#   ('look', 1),
#   ('forward', 1),
#   ('terms', 1),
#   ('body', 1),
#   ('wise', 1),
#   ('bit', 2),
#   ('preparation', 1),
#   ('yesterday', 1),
#   ('sorting', 1),
#   ('bodies', 1),
#   ('needed', 1),
#   ('individually', 1),
#   ('ready', 1),
#   ('gt', 2),
#   ('record', 3),
#   ('vs', 1),
#   ('csk', 1),
#   ('makes', 1),
#   ('play', 1),
#   ('end', 1),
#   ('day', 2),
#   ('plays', 1),
#   ('sticking', 1),
#   ('processes', 1),
#   ('making', 3),
#   ('sure', 3),
#   ('lot', 2),
#   ('game', 1),
#   ('seriously', 1),
#   ('good', 1),
#   ('team', 1),
#   ('chasing', 2),
#   ('year', 2),
#   ('half', 1),
#   ('think', 2),
#   ('clear', 1),
#   ('started', 1),
#   ('confidence', 1),
#   ('leading', 1),
#   ('use', 1),
#   ('flow', 1),
#   ('staying', 1),
#   ('calm', 1),
#   ('calmer', 1),
#   ('opposition', 1),
#   ('self', 1),
#   ('belief', 1),
#   ('knowing', 1),
#   ('actually', 1),
#   ('chase', 1)],
#  [('excited', 1),
#   ('looking', 1),
#   ('forward', 1),
#   ('tonight', 5),
#   ('big', 1),
#   ('game', 1),
#   ('hopefully', 1),
#   ('win', 1),
#   ('good', 3),
#   ('season', 1),
#   ('far', 1),
#   ('pretty', 1),
#   ('happy', 1),
#   ('things', 1),
#   ('gone', 1),
#   ('aside', 1),
#   ('happens', 1),
#   ('keeping', 1),
#   ('simple', 1),
#   ('trying', 1),
#   ('exactly', 1),
#   ('backing', 1),
#   ('gameplan', 1),
#   ('building', 1),
#   ('partnership', 1),
#   ('rutu', 1),
#   ('massive', 1),
#   ('advantage', 1),
#   ('playing', 2),
#   ('home', 1),
#   ('got', 2),
#   ('idea', 1),
#   ('plays', 1),
#   ('adjusting', 1),
#   ('soaking', 1),
#   ('freedom', 1),
#   ('putting', 1),
#   ('opposition', 1),
#   ('pressure', 3),
#   ('gt', 1),
#   ('group', 1),
#   ('rounded', 1),
#   ('bases', 1),
#   ('covered', 1),
#   ('little', 1),
#   ('bit', 1),
#   ('better', 1),
#   ('early', 1),
#   ('bat', 1),
#   ('ball', 1),
#   ('play', 1),
#   ('favour', 1)],
#  [('prakash', 1),
#   ('joshua', 1),
#   ('little', 2),
#   ('alzarri', 1),
#   ('joseph', 1),
#   ('bowling', 2),
#   ('pitch', 1),
#   ('involved', 1),
#   ('today', 1),
#   ('rejoined', 1),
#   ('squad', 1),
#   ('rcb', 1),
#   ('game', 1),
#   ('sunday', 1),
#   ('gt', 1),
#   ('trained', 1),
#   ('night', 1),
#   ('said', 1),
#   ('dasun', 1),
#   ('shanaka', 1),
#   ('right', 1)],
#  [('m', 2),
#   ('square', 1),
#   ('boundary', 2),
#   ('straight', 1),
#   ('spinners', 2),
#   ('licking', 1),
#   ('lips', 1),
#   ('dressing', 1),
#   ('room', 1),
#   ('dry', 2),
#   ('definitely', 1),
#   ('turn', 1),
#   ('patches', 1),
#   ('offer', 1),
#   ('plenty', 1),
#   ('quality', 1),
#   ('sides', 1),
#   ('slow', 1),
#   ('match', 2),
#   ('progresses', 1),
#   ('winning', 1),
#   ('total', 1),
#   ('bat', 1),
#   ('runs', 1),
#   ('board', 1),
#   ('final', 1),
#   ('matter', 1),
#   ('reckons', 1)],
#  [('says', 1),
#   ('tonight', 1),
#   ('game', 1),
#   ('played', 2),
#   ('pitch', 1),
#   ('number', 1),
#   ('saw', 1),
#   ('run', 1),
#   ('fest', 1),
#   ('csk', 1),
#   ('april', 1),
#   ('punjab', 1),
#   ('kings', 1)],
#  [('team', 1),
#   ('changes', 2),
#   ('tonight', 1),
#   ('big', 1),
#   ('game', 1),
#   ('place', 1),
#   ('final', 1),
#   ('offer', 1),
#   ('expect', 1),
#   ('captains', 2),
#   ('drastic', 1),
#   ('playing', 1),
#   ('xi', 1),
#   ('impact', 1),
#   ('substitutes', 1),
#   ('continuity', 1),
#   ('keyword', 1),
#   ('ideally', 1),
#   ('going', 1),
#   ('xis', 1),
#   ('worked', 1),
#   ('season', 1)],
#  [('league', 4),
#   ('games', 1),
#   ('spread', 1),
#   ('period', 1),
#   ('littleover', 1),
#   ('weeks', 1),
#   ('finally', 1),
#   ('survivors', 1),
#   ('contesting', 1),
#   ('home', 4),
#   ('prized', 1),
#   ('ipl', 2),
#   ('trophy', 1),
#   ('mi', 1),
#   ('time', 2),
#   ('champs', 1),
#   ('csk', 2),
#   ('grab', 1),
#   ('title', 2),
#   ('gujarat', 1),
#   ('titans', 3),
#   ('continue', 1),
#   ('winning', 2),
#   ('spree', 1),
#   ('defend', 1),
#   ('lucknow', 1),
#   ('super', 2),
#   ('giantsbecome', 1),
#   ('champions', 1),
#   ('lot', 1),
#   ('play', 1),
#   ('reaches', 1),
#   ('stretch', 1),
#   ('today', 2),
#   ('qualifier', 1),
#   ('cruised', 1),
#   ('phase', 1),
#   ('comfortably', 1),
#   ('best', 1),
#   ('team', 2),
#   ('display', 1),
#   ('confirm', 1),
#   ('place', 1),
#   ('playoffs', 1),
#   ('emphatically', 1),
#   ('hand', 2),
#   ('kings', 1),
#   ('wait', 2),
#   ('final', 2),
#   ('game', 2),
#   ('knack', 1),
#   ('big', 1),
#   ('moments', 1),
#   ('especially', 1),
#   ('playing', 1),
#   ('winner', 2),
#   ('tonight', 2),
#   ('sunday', 1),
#   ('loser', 1),
#   ('tomorrow', 1),
#   ('qf', 1),
#   ('ahmedabad', 1),
#   ('advantage', 1),
#   ('better', 1),
#   ('rested', 1),
#   ('having', 1),
#   ('played', 1),
#   ('match', 2),
#   ('saturday', 1),
#   ('spilled', 1),
#   ('wee', 1),
#   ('hours', 1),
#   ('yesterday', 1),
#   ('travel', 1),
#   ('telling', 1),
#   ('factor', 1)],
#  [('ms', 1),
#   ('dhoni', 1),
#   ('chennai', 1),
#   ('super', 1),
#   ('kings', 1),
#   ('lap', 1),
#   ('honour', 1),
#   ('chepauk', 1),
#   ('said', 1),
#   ('thank', 1),
#   ('yous', 1),
#   ('fans', 1),
#   ('season', 1),
#   ('began', 1),
#   ('possibility', 1),
#   ('demigod', 1),
#   ('years', 2),
#   ('walking', 1),
#   ('away', 1),
#   ('sunset', 1),
#   ('months', 1),
#   ('seven', 1),
#   ('games', 1),
#   ('home', 1),
#   ('represented', 1),
#   ('cathartic', 1),
#   ('reunion', 1),
#   ('celebration', 1),
#   ('grand', 1),
#   ('display', 1),
#   ('gratitude', 1),
#   ('reverence', 1),
#   ('man', 1),
#   ('team', 1),
#   ('highest', 1),
#   ('pedestal', 1),
#   ('success', 1),
#   ('massive', 1),
#   ('mural', 1),
#   ('venue', 1)],
#  [('tuesday', 1),
#   ('presents', 1),
#   ('csk', 1),
#   ('faithful', 1),
#   ('chance', 1),
#   ('season', 1),
#   ('raise', 1),
#   ('roof', 1),
#   ('team', 1),
#   ('attempts', 1),
#   ('swift', 1),
#   ('entry', 1),
#   ('final', 1),
#   ('appearance', 1),
#   ('eventually', 1),
#   ('try', 1),
#   ('match', 1),
#   ('mumbai', 1),
#   ('indians', 1),
#   ('number', 1),
#   ('ipl', 1),
#   ('titles', 1),
#   ('won', 1)],
#  [('gujarat', 1),
#   ('titans', 1),
#   ('time', 1),
#   ('emotional', 1),
#   ('storylines', 1),
#   ('night', 2),
#   ('ago', 1),
#   ('hardik', 1),
#   ('pandya', 1),
#   ('fielded', 1),
#   ('strength', 1),
#   ('team', 1),
#   ('confirmed', 1),
#   ('play', 1),
#   ('qualifier', 1),
#   ('preached', 1),
#   ('need', 1),
#   ('maintain', 1),
#   ('good', 1),
#   ('habits', 1),
#   ('momentum', 1),
#   ('cut', 1),
#   ('throat', 1),
#   ('decision', 1),
#   ('ended', 1),
#   ('heartbreak', 1),
#   ('india', 1),
#   ('favourite', 1),
#   ('sons', 1),
#   ('virat', 1),
#   ('kohli', 1),
#   ('sunk', 1),
#   ('chair', 1),
#   ('complete', 1),
#   ('despair', 1),
#   ('late', 1),
#   ('sunday', 1),
#   ('following', 1),
#   ('rcb', 1),
#   ('league', 1),
#   ('stage', 1),
#   ('ouster', 1),
#   ('gt', 1),
#   ('brand', 1),
#   ('ruthless', 1),
#   ('approach', 1),
#   ('enabled', 1),
#   ('maintained', 1),
#   ('distance', 1),
#   ('traffic', 1),
#   ('middle', 1),
#   ('points', 1),
#   ('table', 1),
#   ('season', 1)],
#  [('concerns', 1),
#   ('fatigue', 1),
#   ('short', 1),
#   ('turnaround', 1),
#   ('time', 1),
#   ('league', 1),
#   ('game', 2),
#   ('qualifier', 1),
#   ('unfounded', 1),
#   ('week', 1),
#   ('pandya', 2),
#   ('team', 1),
#   ('played', 1),
#   ('shorter', 1),
#   ('gap', 1),
#   ('matches', 1),
#   ('going', 1),
#   ('evening', 1),
#   ('fixture', 2),
#   ('jaipur', 1),
#   ('friday', 1),
#   ('travelling', 1),
#   ('home', 1),
#   ('saturday', 1),
#   ('featuring', 1),
#   ('afternoon', 1),
#   ('sunday', 1),
#   ('turn', 1),
#   ('won', 1),
#   ('perceived', 1),
#   ('advantage', 1),
#   ('csk', 1),
#   ('playing', 1),
#   ('venue', 1),
#   ('gt', 1),
#   ('season', 1),
#   ('negated', 1),
#   ('fact', 1),
#   ('sure', 1),
#   ('conditions', 1),
#   ('expect', 1),
#   ('excellent', 1),
#   ('road', 1),
#   ('away', 1),
#   ('wins', 1)],
#  [('high', 1),
#   ('stakes', 1),
#   ('game', 1),
#   ('come', 1),
#   ('fine', 1),
#   ('match', 1),
#   ('ups', 1),
#   ('finer', 1),
#   ('margins', 1),
#   ('teams', 1),
#   ('shown', 1),
#   ('identical', 1),
#   ('tendencies', 1),
#   ('squeeze', 1),
#   ('ounce', 1),
#   ('ability', 1),
#   ('squads', 1),
#   ('disposal', 1)],
#  [('hot', 1),
#   ('evening', 1),
#   ('offing', 1),
#   ('temperatures', 1),
#   ('hit', 1),
#   ('high', 1),
#   ('conditions', 1),
#   ('venue', 2),
#   ('suited', 1),
#   ('batters', 1),
#   ('early', 1),
#   ('wickets', 1),
#   ('slowed', 1),
#   ('tournament', 1),
#   ('progressed', 1),
#   ('reflected', 1),
#   ('scores', 1),
#   ('average', 1),
#   ('innings', 1),
#   ('total', 1),
#   ('came', 1),
#   ('games', 1),
#   ('csk', 1),
#   ('outspun', 1),
#   ('game', 1),
#   ('kkr', 1)],
#  [('tuesday', 1),
#   ('game', 1),
#   ('played', 2),
#   ('pitch', 1),
#   ('csk', 1),
#   ('pbks', 1),
#   ('high', 1),
#   ('scoring', 1),
#   ('entertainer', 1),
#   ('home', 1),
#   ('team', 1),
#   ('chased', 1),
#   ('ball', 1)],
#  [('deepak', 1),
#   ('chahar', 2),
#   ('wicket', 1),
#   ('taking', 1),
#   ('form', 1),
#   ('powerplay', 1),
#   ('early', 1),
#   ('match', 1),
#   ('shubman', 1),
#   ('gill', 2),
#   ('crucial', 1),
#   ('direction', 1),
#   ('game', 2),
#   ('takes', 1),
#   ('arrives', 1),
#   ('scores', 1),
#   ('scored', 1),
#   ('runs', 1),
#   ('balls', 1),
#   ('faced', 1),
#   ('csk', 1),
#   ('pacer', 1),
#   ('dismissed', 1),
#   ('twice', 1)],
#  [('ajinkya', 1),
#   ('rahane', 1),
#   ('flattered', 1),
#   ('deceive', 1),
#   ('home', 1),
#   ('games', 1),
#   ('admirable', 1),
#   ('record', 1),
#   ('mohammed', 1),
#   ('shami', 1),
#   ('smashing', 1),
#   ('strike', 1),
#   ('rate', 1),
#   ('getting', 1),
#   ('dismissed', 1),
#   ('hardik', 1),
#   ('pandya', 1),
#   ('dhoni', 1),
#   ('turn', 1),
#   ('ravindra', 1),
#   ('jadeja', 1),
#   ('got', 1),
#   ('gt', 1),
#   ('captain', 1),
#   ('twice', 1),
#   ('balls', 1),
#   ('given', 1),
#   ('away', 1),
#   ('runs', 1)],
#  [('vijay', 1),
#   ('shankar', 1),
#   ('regained', 1),
#   ('fitness', 1),
#   ('ahead', 2),
#   ('sunday', 1),
#   ('league', 1),
#   ('game', 1),
#   ('rcb', 2),
#   ('came', 1),
#   ('impact', 2),
#   ('sub', 2),
#   ('bat', 2),
#   ('considering', 1),
#   ('dasun', 1),
#   ('shanaka', 1),
#   ('lot', 1),
#   ('ball', 1),
#   ('gt', 2),
#   ('turn', 1),
#   ('joshua', 1),
#   ('little', 1),
#   ('xi', 1),
#   ('left', 1),
#   ('arm', 1),
#   ('pacer', 1),
#   ('away', 1),
#   ('ireland', 1),
#   ('bangladesh', 1),
#   ('series', 1),
#   ('returned', 1),
#   ('squad', 1),
#   ('weekend', 1),
#   ('fixture', 1),
#   ('trained', 1),
#   ('chennai', 1),
#   ('eve', 1),
#   ('qualifier', 1)],
#  [('ruturaj', 1),
#   ('gaikwad', 1),
#   ('hit', 1),
#   ('gt', 1),
#   ('shami', 2),
#   ('found', 1),
#   ('ways', 1),
#   ('lid', 1),
#   ('scoring', 1),
#   ('early', 1),
#   ('veteran', 1),
#   ('pacer', 1),
#   ('conceded', 1),
#   ('runs', 1),
#   ('balls', 1),
#   ('bowled', 2),
#   ('csk', 2),
#   ('opener', 1),
#   ('excellent', 1),
#   ('scorer', 1),
#   ('season', 1),
#   ('devon', 1),
#   ('conway', 1),
#   ('dismissing', 1),
#   ('twice', 1),
#   ('deliveries', 1),
#   ('ipl', 1)],
#  [('mohit', 1),
#   ('sharma', 1),
#   ('returns', 1),
#   ('city', 1),
#   ('tournament', 2),
#   ('wickets', 1),
#   ('matches', 1),
#   ('troubled', 1),
#   ('ambati', 1),
#   ('rayudu', 1),
#   ('getting', 1),
#   ('occasions', 1),
#   ('balls', 1),
#   ('giving', 1),
#   ('away', 1),
#   ('runs', 1)],
#  [('gujarat', 1),
#   ('titans', 1),
#   ('best', 2),
#   ('run', 1),
#   ('tally', 2),
#   ('death', 1),
#   ('overs', 1),
#   ('season', 1),
#   ('losing', 1),
#   ('fewest', 1),
#   ('wickets', 1),
#   ('phase', 1),
#   ('second', 1),
#   ('sixes', 1),
#   ('period', 1)],
#  [('shivam', 1),
#   ('dube', 1),
#   ('incredible', 1),
#   ('strike', 1),
#   ('rate', 1),
#   ('spin', 1),
#   ('season', 1),
#   ('interestingly', 1),
#   ('hit', 1),
#   ('fours', 1),
#   ('tonked', 1),
#   ('sixes', 1)],
#  [('games', 1),
#   ('csk', 1),
#   ('picked', 3),
#   ('wickets', 2),
#   ('gujarat', 1),
#   ('titans', 1),
#   ('powerplay', 1),
#   ('season', 1),
#   ('shami', 1)],
#  [('half', 1),
#   ('ipl', 2),
#   ('missing', 1),
#   ('big', 1),
#   ('ones', 1),
#   ('getting', 1),
#   ('lot', 1),
#   ('thankfully', 1),
#   ('working', 1),
#   ('business', 1),
#   ('end', 1)],
#  [('think', 2),
#   ('death', 2),
#   ('bowling', 2),
#   ('confidence', 2),
#   ('important', 1),
#   ('tushar', 1),
#   ('developed', 2),
#   ('able', 1),
#   ('execute', 1),
#   ('pressure', 1),
#   ('playing', 1),
#   ('players', 1),
#   ('helps', 1),
#   ('bowlers', 1),
#   ('taken', 1),
#   ('responsibility', 1),
#   ('pathirana', 1),
#   ('natural', 1),
#   ('deshpande', 1)]]
