# %% [markdown]
# Extract a particular file from cricsheet website and create a DataFrame.

# %%
import requests
import io
import zipfile
import re
import pandas as pd
import numpy as np

# %%
# Settings configurations

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#url = "https://cricsheet.org/downloads/ipl_csv2.zip"
url = "https://cricsheet.org/downloads/recently_added_2_csv2.zip"

# Send a GET request to the URL and retrieve the response
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Read the content of the response as bytes
    content = response.content

    # Create a file-like object from the bytes data
    zip_file = zipfile.ZipFile(io.BytesIO(content))

    # Extract and process CSV files matching the pattern
    csv_files = [file for file in zip_file.namelist() if file.endswith('.csv') and '_info' not in file]
    print("Here are the new csv files found :- \n")
    print(csv_files)
    
    for file in csv_files:
        try:
            # Extract the file from the zip archive
            zip_file.extract(file)

            # Read the extracted CSV file as a DataFrame
            df = pd.read_csv(file)

            # Perform your desired tasks with the data
            # ...

        except KeyError:
            print(f"File {file} not found in the zip archive.")

    # Close the zip file
    zip_file.close()

else:
    print("Failed to retrieve data from the URL.")

# Continue with your other tasks or operations
# ...
# Out:
# Here are the new csv files found :-
#
# ['1368851.csv', '1367725.csv', '1367726.csv', '1367729.csv', '1339622.csv', '1367727.csv', '1347415.csv', '1347416.csv', '1347417.csv', '1359521.csv', '1359522.csv', '1359523.csv', '1359524.csv']

# %%
df.head()
# Out:
#    match_id  season  start_date                        venue  innings  ball  \
# 0   1359524    2023  2023-05-06  Arun Jaitley Stadium, Delhi        1   0.1
# 1   1359524    2023  2023-05-06  Arun Jaitley Stadium, Delhi        1   0.2
# 2   1359524    2023  2023-05-06  Arun Jaitley Stadium, Delhi        1   0.3
# 3   1359524    2023  2023-05-06  Arun Jaitley Stadium, Delhi        1   0.4
# 4   1359524    2023  2023-05-06  Arun Jaitley Stadium, Delhi        1   0.5
#
#                   batting_team    bowling_team  striker   non_striker  \
# 0  Royal Challengers Bangalore  Delhi Capitals  V Kohli  F du Plessis
# 1  Royal Challengers Bangalore  Delhi Capitals  V Kohli  F du Plessis
# 2  Royal Challengers Bangalore  Delhi Capitals  V Kohli  F du Plessis
# 3  Royal Challengers Bangalore  Delhi Capitals  V Kohli  F du Plessis
# 4  Royal Challengers Bangalore  Delhi Capitals  V Kohli  F du Plessis
#
#      bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty  \
# 0  KK Ahmed             0       0    NaN      NaN   NaN      NaN      NaN
# 1  KK Ahmed             4       0    NaN      NaN   NaN      NaN      NaN
# 2  KK Ahmed             0       0    NaN      NaN   NaN      NaN      NaN
# 3  KK Ahmed             0       0    NaN      NaN   NaN      NaN      NaN
# 4  KK Ahmed             2       0    NaN      NaN   NaN      NaN      NaN
#
#   wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 0         NaN              NaN                NaN                     NaN
# 1         NaN              NaN                NaN                     NaN
# 2         NaN              NaN                NaN                     NaN
# 3         NaN              NaN                NaN                     NaN
# 4         NaN              NaN                NaN                     NaN
